# %%
import pandas as pd

# %%
data = pd.read_csv("HousingData.csv")
data.head
# Out:
# <bound method NDFrame.head of         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
data.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
data.fillna(data.mean(), inplace=True)

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
data.info
# Out:
# <bound method DataFrame.info of         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.200000  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900000  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.100000  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.800000  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200000  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.100000  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.700000  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300000  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  68.518519  2.5050    1  273
#
# ...

# %%
data.to_csv("boston_housing_full.csv", index=False)

# %%
#Grafik 1 : AGE ile MEDV ilişkisi
data.plot(kind='scatter', x='AGE', y='MEDV', title='AGE ile MEDV (Fiyat) İlişkisi', alpha=0.6, figsize=(10,6))
# Out:
# <Axes: title={'center': 'AGE ile MEDV (Fiyat) İlişkisi'}, xlabel='AGE', ylabel='MEDV'>

# %%
#Grafik 1 : AGE ile MEDV ilişkisi
age_and_price = data[['AGE', 'MEDV']]
age_and_price
# Out:
#            AGE  MEDV
# 0    65.200000  24.0
# 1    78.900000  21.6
# 2    61.100000  34.7
# 3    45.800000  33.4
# 4    54.200000  36.2
# ..         ...   ...
# 501  69.100000  22.4
# 502  76.700000  20.6
# 503  91.000000  23.9
# 504  89.300000  22.0
# 505  68.518519  11.9
#
# [506 rows x 2 columns]

# %%
#Grafik 2 : CRIM ile MEDV ilişkisi
data.plot(kind='scatter', x='CRIM', y='MEDV', title='CRIM ile MEDV (Fiyat) İlişkisi', alpha=0.6, figsize=(10,6), color='red')
# Out:
# <Axes: title={'center': 'CRIM ile MEDV (Fiyat) İlişkisi'}, xlabel='CRIM', ylabel='MEDV'>

# %%
#Grafik 2 : CRIM ile MEDV ilişkisi
crim_and_price = data[['CRIM', 'MEDV']]
crim_and_price
# Out:
#         CRIM  MEDV
# 0    0.00632  24.0
# 1    0.02731  21.6
# 2    0.02729  34.7
# 3    0.03237  33.4
# 4    0.06905  36.2
# ..       ...   ...
# 501  0.06263  22.4
# 502  0.04527  20.6
# 503  0.06076  23.9
# 504  0.10959  22.0
# 505  0.04741  11.9
#
# [506 rows x 2 columns]
